# %% [markdown]
# # Map
#
# _Apr 15th, 2019_
#
# ## Table of Contents
#
# <div class='alert alert-block alert-info' style='margin-top: 20px'>
#     <li><a href='#ref1'>folium</a>
# </div>

# %%
import pandas as pd
import folium

# %%
data = pd.read_csv('./data/institutional_provider_2014to2017_q4.csv', 
                          usecols = ['sitename', 'zip', 'year'],
                          dtype = {'zip': object})

# %%
data.head()
# Out:
#                                             sitename  year    zip
# 0  "CLOVE LAKES HEALTH CARE AND REHABILITATION CE...  2014  10314
# 1  "CLOVE LAKES HEALTH CARE AND REHABILITATION CE...  2014  10314
# 2                 "EXCELLENT HOMECARE SERVICES, LLC"  2014  11211
# 3              "HAYM SOLOMON HOME FOR THE AGED, LLC"  2014  11214
# 4              "HAYM SOLOMON HOME FOR THE AGED, LLC"  2014  11214

# %% [markdown]
# <a id='ref1'></a>
# ## folium
# ### 2017

# %%
data_2017 = data[data['year'] == 2017]
data_2017.head(3)
# Out:
#                                               sitename  year    zip
# 86753                             LACONIA NURSING HOME  2017  10466
# 86754                   CITY CHOICE HOME CARE SERVICES  2017  11235
# 86755  NYU LANGONE MED CENTER LEVIT MED ARTS PAVILLION  2017  11236

# %%
data_2017 = data_2017[['sitename', 'zip']]
data_2017.head(3)
# Out:
#                                               sitename    zip
# 86753                             LACONIA NURSING HOME  10466
# 86754                   CITY CHOICE HOME CARE SERVICES  11235
# 86755  NYU LANGONE MED CENTER LEVIT MED ARTS PAVILLION  11236

# %%
zip_groups = data_2017.groupby("zip")
sizes = pd.DataFrame(zip_groups.size())
sizes.rename(columns={0:"size"}, inplace=True)
sizes.reset_index(level=0, inplace=True)
sizes['Zip'] = sizes['zip'] # to match the column name in file zipcode.geojson
sizes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 3 columns):
# zip     210 non-null object
# size    210 non-null int64
# Zip     210 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB

# %%
sizes.head(3)
# Out:
#      zip  size    Zip
# 0  10001   603  10001
# 1  10002   536  10002
# 2  10003   613  10003

# %%
#import folium
#Center the map at Times Square
m = folium.Map(location=[40.7589, -73.9851], zoom_start=11)
m.choropleth(geo_data='./data/zipcode.geojson', data=sizes,
             columns=['Zip','size'],
             key_on='feature.properties.postalCode',
             fill_color='RdYlGn', fill_opacity=0.7, line_opacity=0.8,
             legend_name='Distribution of Institutional Providers')
folium.LayerControl().add_to(m)
# Out:
# /Users/Ivy_Zhang/anaconda3/lib/python3.6/site-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('./map/map_2017q4.html')

# %% [markdown]
# ### 2014 - 2016

# %%
def map_by_year(year, data=data):
    data_yr = data[data['year'] == year]
    data_yr = data_yr[['sitename', 'zip']]
    
    zip_groups = data_yr.groupby("zip")
    sizes = pd.DataFrame(zip_groups.size())
    sizes.rename(columns={0:"size"}, inplace=True)
    sizes.reset_index(level=0, inplace=True)
    sizes['Zip'] = sizes['zip'] # to match the column name in file zipcode.geojson
    sizes.info()
    
    #Center the map at Times Square
    m = folium.Map(location=[40.7589, -73.9851], zoom_start=11)
    m.choropleth(geo_data='./data/zipcode.geojson', data=sizes,
                 columns=['Zip','size'],
                 key_on='feature.properties.postalCode',
                 fill_color='RdYlGn', fill_opacity=0.7, line_opacity=0.8,
                 legend_name='Distribution of Institutional Providers')
    folium.LayerControl().add_to(m)
    
    m.save('./map/map_%sq4.html' % year)

# %%
map_by_year(2017)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 3 columns):
# zip     210 non-null object
# size    210 non-null int64
# Zip     210 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB
# /Users/Ivy_Zhang/anaconda3/lib/python3.6/site-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
map_by_year(2016)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 3 columns):
# zip     208 non-null object
# size    208 non-null int64
# Zip     208 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB
# /Users/Ivy_Zhang/anaconda3/lib/python3.6/site-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
map_by_year(2015)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 3 columns):
# zip     207 non-null object
# size    207 non-null int64
# Zip     207 non-null object
# dtypes: int64(1), object(2)
# memory usage: 4.9+ KB
# /Users/Ivy_Zhang/anaconda3/lib/python3.6/site-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
map_by_year(2014)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 3 columns):
# zip     208 non-null object
# size    208 non-null int64
# Zip     208 non-null object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB
# /Users/Ivy_Zhang/anaconda3/lib/python3.6/site-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
